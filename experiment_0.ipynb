# %% [markdown]
# Experiment 0 : Introduction to python

# %%
# Naman Bothra
# PRN - 25070123078

print("Hello World")
# Out:
# Hello World

# %%
arr =[1,2,3]
print(arr)
# Out:
# [1, 2, 3]

# %%
print("Naman",10,[1,2,3])
# Out:
# Naman 10 [1, 2, 3]

# %%
x = "Naman"
y = 10
z = [1,2,3]
print(x,"\n",y,"\n",z)
# Out:
# Naman
#  10
#  [1, 2, 3]

# %%
x = "Naman"
y = 10
z = [1,2,3]
print(x,y,z,sep="\n")
# Out:
# Naman
# 10
# [1, 2, 3]
